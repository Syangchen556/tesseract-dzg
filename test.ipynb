# %%
import pytesseract
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pytesseract
#       2 from PIL import Image
#
# ModuleNotFoundError: No module named 'pytesseract'

# %%
img= Image.open(r"C:\tesseract-dzg\tesstrain\data\dzg-ground-truth\dzo_DDC_Rinzin_8.tif")
text = pytesseract.image_to_string(img, lang='dzg')
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img= Image.open(r"C:\tesseract-dzg\tesstrain\data\dzg-ground-truth\dzo_DDC_Rinzin_8.tif")
#       2 text = pytesseract.image_to_string(img, lang='dzg')
#       3 print(text)
#
# NameError: name 'Image' is not defined
